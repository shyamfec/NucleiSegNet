# %% [markdown]
# <a href="https://colab.research.google.com/github/DevikalyanDas/NucleiSegnet-Paper-with-Code/blob/main/nucleisegnet_all.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install spams
# Out:
# ...
#      |████████████████████████████████| 1.6MB 7.4MB/s
# ...
#   Created wheel for spams: filename=spams-2.6.2.5-cp37-cp37m-linux_x86_64.whl size=4516323 sha256=30d727a0454abf3929c04e28838667c6fc5d7ada5788b519a4e5966c0c973ad1
#   Stored in directory: /root/.cache/pip/wheels/ba/6f/08/d9d013b9e3ac5ce8f10e67573f38a366c907f99299d5d7711a
# Successfully built spams
# ...

# %%
cd '/content/drive/MyDrive/code_nucleisegnet'
# Out:
# /content/drive/MyDrive/code_nucleisegnet

# %%
# !python color_norm.py
# Out:
# stain normalizing and cropping patches of train images and masks ...
# 100% 24/24 [01:37<00:00,  4.08s/it]
# stain normalizing and cropping patches of validation images and masks ...
# 100% 6/6 [00:23<00:00,  3.95s/it]
# stain normalizing and cropping patches of test images ...
# 100% 14/14 [00:51<00:00,  3.69s/it]
# 100% 14/14 [00:00<00:00, 16.48it/s]
# 100% 6/6 [00:00<00:00, 15.92it/s]
# 100% 24/24 [00:01<00:00, 16.01it/s]

# %%
# !python main.py
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# separable_conv2d (SeparableConv (None, 256, 256, 32) 1344        batch_normalization[0][0]
# __________________________________________________________________________________________________
# ...

# %%
# !python test.py
# Out:
# Predicting the masks ===========>
# 100% 224/224 [00:16<00:00, 13.49it/s]
# Joining the segmented patches to original sized masks ===========>
# Writing segmented masks to image files ===========>
# 100% 14/14 [00:00<00:00, 248.11it/s]
# Segmented images are saved in /content/results
# Scores for the segmented output ===========>
# ID-TCGA-21-5784-01Z-00-DX1  IOU: 0.671, DICE: 0.803
# ID-TCGA-21-5786-01Z-00-DX1  IOU: 0.589, DICE: 0.742
# ID-TCGA-AY-A8YK-01A-01-TS1  IOU: 0.614, DICE: 0.761
# ID-TCGA-B0-5698-01Z-00-DX1  IOU: 0.621, DICE: 0.766
# ID-TCGA-B0-5710-01Z-00-DX1  IOU: 0.687, DICE: 0.814
# ID-TCGA-CH-5767-01Z-00-DX1  IOU: 0.645, DICE: 0.784
# ID-TCGA-DK-A2I6-01A-01-TS1  IOU: 0.797, DICE: 0.887
# ID-TCGA-E2-A14V-01Z-00-DX1  IOU: 0.749, DICE: 0.857
# ID-TCGA-E2-A1B5-01Z-00-DX1  IOU: 0.67, DICE: 0.803
# ID-TCGA-G2-A2EK-01A-02-TSB  IOU: 0.689, DICE: 0.816
# ID-TCGA-G9-6362-01Z-00-DX1  IOU: 0.647, DICE: 0.785
# ID-TCGA-KB-A93J-01A-01-TS1  IOU: 0.759, DICE: 0.863
# ...

# %%
# !python overlay_mask.py
# Out:
# Creating overlay images ===========>
# 100% 14/14 [00:01<00:00, 11.44it/s]
# Created Overlay images ===========>
